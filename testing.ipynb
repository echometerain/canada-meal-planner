# %%
import pandas as pd
import numpy as np

merged = pd.read_csv("./csv/merged.csv").set_index("FoodDescription")
nu_name = pd.read_csv("./csv/nu_name.csv").set_index("NutrientID")
nu_amount = pd.read_csv("./csv/nu_amount.csv")
daily = pd.read_csv("./csv/daily.csv")

# %%
merged
# Out:
#                                                     FoodID  \
# FoodDescription
# Cheese souffle                                           2
# Chop suey, with meat, canned                             4
# Chinese dish, chow mein, chicken                         5
# Corn fritter                                             6
# Beef pot roast, with browned potatoes, peas and...       7
# ...                                                    ...
# Orange juice, frozen concentrate, diluted, with...  503365
# Margarine, tub, hydrogenated, soybean oil           503366
# Margarine, tub, hydrogenated, canola oil            503367
# Chocolate syrup, thin type, less sugar, with ad...  503379
# Granola bar, chewy, high fibre, oats and chocolate  503380
#
#                                                                                      FoodDescriptionF  \
# FoodDescription
# Cheese souffle                                                                     Soufflé au fromage
# ...

# %%
daily.head()
# Out:
#   Components Unit  Type     0     0.5     1     4   9 m  14 m  19 m  ...  \
# 0  Vitamin A   μg   Min   NaN     NaN   210   275   445   630   625  ...
# 1  Vitamin A   μg  Good   400   500.0   300   400   600   900   900  ...
# 2  Vitamin A   μg   Max   600   600.0   600   900  1700  2800  3000  ...
# 3  Vitamin A   IU   Min   NaN     NaN   700   917  1483  2100  2083  ...
# 4  Vitamin A   IU  Good  1333  1667.0  1000  1333  2000  3000  3000  ...
#
#    19 f  31 f  51 f  70 f   0 p  19 p  31 p   0 l  19 l  31 l
# 0   500   500   500   500   530   550   550   885   900   900
# 1   700   700   700   700   750   770   770  1200  1300  1300
# 2  3000  3000  3000  3000  2800  3000  3000  2800  3000  3000
# 3  1667  1667  1667  1667  1767  1833  1833  2950  3000  3000
# 4  2333  2333  2333  2333  2500  2567  2567  4000  4333  4333
#
# [5 rows x 25 columns]

# %%
nu_amount
# Out:
#         FoodID  NutrientID  NutrientValue
# 0            2         203           9.54
# 1            2         204          15.70
# 2            2         205           5.91
# 3            2         207           1.67
# 4            2         208         204.00
# ...        ...         ...            ...
# 524669  503380         861           0.00
# 524670  503380         862          12.40
# 524671  503380         863           3.30
# 524672  503380         874           0.00
# 524673  503380         875           0.00
#
# [524674 rows x 3 columns]

# %%
nu_name
# Out:
#            NutrientUnit                                       NutrientName  \
# NutrientID
# 203                   g                                            Protein
# 204                   g                                 Fat (Total Lipids)
# 205                   g                Carbohydrate, Total (By Difference)
# 207                   g                                         Ash, Total
# 208                kCal                              Energy (Kilocalories)
# ...                 ...                                                ...
# 847                   g      Fatty Acids, Monounsaturated, 12:1, Lauroleic
# 848                   g                Fatty Acids, Polyunsaturated, 22:3,
# 849                   g  Fatty Acids, Polyunsaturated, 22:2, Docosadienoic
# 868                   g     Fatty Acids, Polyunsaturated, Total Omega  N-3
# 869                   g    Fatty Acids, Polyunsaturated, Total Omega   N-6
#
# ...
